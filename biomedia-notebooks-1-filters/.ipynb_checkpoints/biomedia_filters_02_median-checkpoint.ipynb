# %%
# %matplotlib inline

# %%
import math
import numpy as np
import matplotlib.pyplot as plt


from skimage import io
from skimage import filters
from skimage.morphology import disk

# %% [markdown]
# ## Median filter

# %% [markdown]
# The median filter replaces the center pixel by taking the median of all the pixel values in the local neighbourhood. It is a non-linear filter but provides certain advantages when used for removing image noise. Note how the size of the filter is being defined.

# %%
image = io.imread("../images/1200px-X-ray_of_normal_hand_by_dorsoplantar_projection.jpg")

# %%
filtered_image = filters.median(image, disk(5))

# %%
fig, ax = plt.subplots(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.subplot(1, 2, 2)
plt.imshow(filtered_image, cmap='gray')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Explore:</b> Compare the result of the median filter with Gaussian smoothing. The median filter will preserve the position of the discontinuities or edges in the image. Try to apply very large filter to the image to observe this effect.
